# %%
import geopandas as gpd

# %%
segments_with_risk = gpd.read_parquet("../notebooks/data/panel/segments_with_risk.parquet")
segments_with_risk = segments_with_risk.loc[:, ["counter_name", "year", "month", "geometry", "latitude", "longitude"
                                                "total_accidents", "sum_strava_total_trip_count", "street_name", "rr_eb"]]
original_crs = segments_with_risk.crs

# %%
segments_with_risk.latitude
# Out:
# 0         52.529021
# 1         52.529021
# 2         52.529021
# 3         52.529021
# 4         52.529021
#             ...
# 260095    52.515498
# 260096    52.515498
# 260097    52.515498
# 260098    52.515498
# 260099    52.515498
# Name: latitude, Length: 260100, dtype: float64

# %% [markdown]
# aggregate dataframe over all years, months

# %%
agg_logic = {
    'total_accidents': 'sum',
    'sum_strava_total_trip_count': 'sum',
    'geometry': 'first',
    'street_name': 'first',
    'rr_eb': 'first'
}

# Perform the aggregation
df_aggregated = segments_with_risk.groupby('counter_name').agg(agg_logic).reset_index()
df_aggregated = gpd.GeoDataFrame(df_aggregated, geometry='geometry', crs=original_crs)

# %%
print(df_aggregated.total_accidents.describe())
# Out:
# count    4335.000000
# mean        2.353172
# std         4.114487
# min         0.000000
# 25%         0.000000
# 50%         1.000000
# 75%         3.000000
# max        57.000000
# Name: total_accidents, dtype: float64

# %%
print(df_aggregated.sum_strava_total_trip_count.describe())
# Out:
# count      4335.000000
# mean      29030.116494
# std       43805.850980
# min          35.000000
# 25%        3527.500000
# 50%       13680.000000
# 75%       37180.000000
# max      586505.000000
# Name: sum_strava_total_trip_count, dtype: float64

# %%
mask1 = (df_aggregated.total_accidents > 20) & (df_aggregated.sum_strava_total_trip_count > 50000.0)
mask2 = (df_aggregated.total_accidents > 20) & (df_aggregated.sum_strava_total_trip_count < 10000.0)

# %%
df_aggregated[mask1].head()
# Out:
#             counter_name  total_accidents  sum_strava_total_trip_count  \
# 671   streetsegment_1677             26.0                      59485.0
# 1170  streetsegment_2143             27.0                      80685.0
# 1251  streetsegment_2223             37.0                      72610.0
# 1265  streetsegment_2236             35.0                      94065.0
# 1276  streetsegment_2246             22.0                      56855.0
#
#                                                geometry         street_name  \
# 671   LINESTRING (392317.91 5816520.498, 392336.166 ...  streetsegment_1677
# 1170  LINESTRING (389863.308 5821905.647, 389894.99 ...  streetsegment_2143
# 1251  LINESTRING (390316.726 5821280.076, 390373.935...  streetsegment_2223
# 1265  LINESTRING (390629.547 5821592.699, 390637.882...  streetsegment_2236
# 1276  LINESTRING (395038.266 5814938.5, 395060.355 5...  streetsegment_2246
#
#          rr_eb
# 671   7.046532
# 1170  5.272712
# 1251  8.055337
# 1265  5.993906
# 1276  6.483980

# %%
df_aggregated[mask2]
# Out:
#             counter_name  total_accidents  sum_strava_total_trip_count  \
# 3641  streetsegment_4765             21.0                       2200.0
#
#                                                geometry         street_name  \
# 3641  LINESTRING (404295.644 5821962.657, 404296.239...  streetsegment_4765
#
#           rr_eb
# 3641  81.916781

# %%
accidents_with_segments = gpd.read_parquet("../data/dataframes/accidents_with_segment.parquet")
accidents_with_segments[accidents_with_segments.counter_name == "streetsegment_4765"]
# Out:
#        ULAND  UREGBEZ  UKREIS  UGEMEINDE  UJAHR  UMONAT  USTUNDE  UWOCHENTAG  \
# 19685     11        0      10         10   2022      11       16           4
# 16359     11        0      10         10   2022       3       16           1
# 8236      11        0      10         10   2019       7       10           7
# 29757     11        0      10         10   2021       5       19           4
# 31855     11        0      10         10   2021       9       12           5
# 30447     11        0      10         10   2021       6       14           3
# 31870     11        0      10         10   2021       8       11           6
# 19735     11        0      10         10   2022      10       11           4
# 29897     11        0      10         10   2021       5       13           7
# 17710     11        0      10         10   2022       6       13           4
# 14602     11        0      10         10   2020      10       16           5
# 1346      11        0      10         10   2018       4       15           4
# 9862      11        0      10         10   2019      11       15           5
# 14580     11        0      10         10   2020      10       15           3
# 30817     11        0      10         10   2021       6       13           5
# 7169      11        0      10         10   2019       5        6           5
# 22306     11        0      10         10   2023       6       17           6
# 9189      11        0      10         10   2019       9       13           7
# 8098      11        0      10         10   2019       7       12           6
# 14623     11        0      10         10   2020      10        8           6
# 33038     11        0      10         10   2021      12       12           3
# 23483     11        0      10         10   2023       9       18           3
# 17918     11        0      10         10   2022       7       21           3
# 9857      11        0      10         10   2019      11        7           6
#
#        UKATEGORIE  UART  ...  IstStrassenzustand  PLST       date  \
# 19685           3     5  ...                 0.0   NaN 2022-11-01
# 16359           3     2  ...                 0.0   NaN 2022-03-01
# 8236            3     5  ...                 NaN   NaN 2019-07-01
# 29757           3     5  ...                 0.0   NaN 2021-05-01
# 31855           3     5  ...                 0.0   NaN 2021-09-01
# 30447           3     5  ...                 0.0   NaN 2021-06-01
# 31870           3     5  ...                 0.0   NaN 2021-08-01
# 19735           2     5  ...                 1.0   NaN 2022-10-01
# 29897           3     5  ...                 0.0   NaN 2021-05-01
# 17710           3     3  ...                 0.0   NaN 2022-06-01
# 14602           3     5  ...                 NaN   NaN 2020-10-01
# 1346            3     6  ...                 NaN   NaN 2018-04-01
# 9862            3     5  ...                 NaN   NaN 2019-11-01
# 14580           3     5  ...                 NaN   NaN 2020-10-01
# 30817           3     5  ...                 0.0   NaN 2021-06-01
# 7169            3     5  ...                 NaN   NaN 2019-05-01
# 22306           3     5  ...                 0.0   1.0 2023-06-01
# 9189            3     5  ...                 NaN   NaN 2019-09-01
# 8098            3     5  ...                 NaN   NaN 2019-07-01
# 14623           2     5  ...                 NaN   NaN 2020-10-01
# 33038           3     5  ...                 1.0   NaN 2021-12-01
# 23483           3     5  ...                 0.0   1.0 2023-09-01
# 17918           3     5  ...                 0.0   NaN 2022-07-01
# 9857            2     5  ...                 NaN   NaN 2019-11-01
#
#                              geometry  acc_id  index_right  \
